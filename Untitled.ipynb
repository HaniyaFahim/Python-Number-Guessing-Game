# %%
import tkinter as tk
from tkinter import *

# %%
root = tk.Tk()

root.title('Learning RadioButtons')
root.geometry('400x400')
root.configure(bg="Yellow")
root.attributes("-alpha",0.5)

L1 = Label(root, text= "Choose a Product Category:", justify=tk.LEFT, padx=20)
L1.pack()

v = IntVar()

B1 = Radiobutton(root, text="Medicine", padx = 20, variable=v, value=1)
B1.pack()


B2 = Radiobutton(root, text="Grocery", padx = 20, variable=v, value=2)
B2.pack()


B3 = Radiobutton(root, text="Clothes", padx = 20, variable=v, value=3)
B3.pack()


B4 = Radiobutton(root, text="Toys", padx = 20, variable=v, value=4)
B4.pack()




B5 = Radiobutton(root, text="Kitchen Utensils", padx = 20, variable=v, value=5)
B5.pack()




B6 = Radiobutton(root, text="Furniture", padx = 20, variable=v, value=6)
B6.pack()



root.mainloop()

# %%
root = tk.Tk()

root.title('Learning RadioButtons')
root.geometry('400x400')
root.configure(bg="Yellow")
root.attributes("-alpha",0.9)

L1 = Label(root, text= "Choose a Sport:", justify=tk.LEFT, padx=20)
L1.grid(row=0,column=0)


v1 = IntVar()
B1 = Checkbutton(root, text="Tennis", variable=v1)
B1.grid(row=1,column=0)

v2 = IntVar()
B2 = Checkbutton(root, text="Cricket", variable=v2)
B2.grid(row=2,column=0)

v3 = IntVar()
B3 = Checkbutton(root, text="Badminton", variable=v3)
B3.grid(row="3",column="0")

v4 = IntVar()
B4 = Checkbutton(root, text="Swimming", variable=v4)
B4.grid(row="4",column="0")

v5 = IntVar()
B5 = Checkbutton(root, text="Ice Skating", variable=v5)
B5.grid(row="5",column="0")

E1 = Entry(root, bd=3)
E1.grid(row="6",column="0")

root.mainloop()

# %%
import tkinter as tk
from tkinter import Tk, font
root=Tk()
font.families()

# %%
import threading
import tkinter as tk
from tkinter import *


win = tk.Tk()

win.title('Guess The Number 10')
win.geometry('400x400')
win.configure(bg="#333")


mylabel = tk.Label(win, text="Guess the number 10", bg="pink" ,font=(  'DilleniaUPC',26,'bold'))
mylabel.grid(row=0,column=2)

#button 1 functions

def click_me1():
    B1.configure(text="Looser" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="30"  ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_mei).start()
    
def click_mei():
    B1.configure(text="" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Now Let's Play Again" ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_me0).start()
    
def click_me0():
    B1.configure(text="Guess 10" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Guess the number 10"  ,font=(  'DilleniaUPC',26,'bold'))
    
#button 2 functions

def click_me2():
    B2.configure(text="Looser" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="40" ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_me).start()
    
def click_me():
    B2.configure(text="" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Now Let's Play Again" ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_mel).start()
    
def click_mel():
    B2.configure(text="Guess 10" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Guess the number 10"  ,font=(  'DilleniaUPC',26,'bold'))
    
#button 3 functions
    
def click_me3():
    B3.configure(text="Loser" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="20"  ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_met).start()
    
def click_met():
    B3.configure(text="" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Now Let's Play Again"  ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_meo).start()
    
def click_meo():
    B3.configure(text="Guess 10" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Guess the number 10"  ,font=(  'DilleniaUPC',26,'bold'))
    


#button 4 functions

def click_me4():
    B4.configure(text="Winner" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="10" ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_men).start()
    
def click_men():
    B4.configure(text="" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Now Let's Play Again"  ,font=(  'DilleniaUPC',26,'bold'))
    threading.Timer(2, click_mec).start()
    
def click_mec():
    B4.configure(text="Guess 10" ,font=(  'Gisha',16,'bold'))
    mylabel.configure(text="Guess the number 10"  ,font=(  'DilleniaUPC',26,'bold'))
    
    
    


B1 = Button(win, text="Guess 10", bg="yellow", command=click_me1  ,font=(  'Gisha',16,'bold'))
B1.grid(row=1,column=1)

B2 = Button(win, text="Guess 10", bg="yellow", command=click_me2 ,font=(  'Gisha',16,'bold'))
B2.grid(row=2,column=1)

B3 = Button(win, text="Guess 10", bg="yellow", command=click_me3 ,font=(  'Gisha',16,'bold'))
B3.grid(row=3,column=1)

B4 = Button(win, text="Guess 10", bg="yellow", command=click_me4 ,font=(  'Gisha',16,'bold'))
B4.grid(row=4,column=1)

win.mainloop()

# %%
from tkinter import *


print("Tkinter is a python library used to create GUI's.And when we combine tkinter and python we can create great GUI Applications Like: Namaz Clock And Number Guessing game.")
print("And GUI stands for Graphical User Interface.")

gui = tk.Tk()

gui.title("Definitions")
gui.geometry("600x600")


def numpy():
    L1.configure(text="Numpy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.")



b1 = Button(gui, text="Numpy",bg="pink",fg="black", command=numpy).grid(row=0,column=0)

L1 = Label(gui, text="").grid(row=0,column=1)

b2 = Button(gui, text="Pandas",bg="pink",fg="black").grid(row=1,column=1)

l2 = Label(gui).grid(row=1,column=2)

b3 = Button(gui, text="Loops",bg="pink",fg="black").grid(row=2,column=2)

l3 = Label(gui).grid(row=2,column=3)

b4 = Button(gui, text="Functions",bg="pink",fg="black").grid(row=3,column=3)

l4 = Label(gui).grid(row=3,column=4)



gui.mainloop()
# Out:
# Tkinter is a python library used to create GUI's.And when we combine tkinter and python we can create great GUI Applications Like: Namaz Clock And Number Guessing game.
# And GUI stands for Graphical User Interface.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\haniy\appdata\local\programs\python\python38\lib\tkinter\__init__.py", line 1895, in __call__
#     return self.func(*args)
#   File "C:\Users\Haniy\AppData\Local\Temp/ipykernel_41364/660337400.py", line 14, in numpy
#     L1.configure(text="Numpy is a Python library used for working with arrays. It also has functions for working in domain of linear algebra, fourier transform, and matrices.")
# AttributeError: 'NoneType' object has no attribute 'configure'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\users\haniy\appdata\local\programs\python\python38\lib\tkinter\__init__.py", line 1895, in __call__
#     return self.func(*args)
# ...
